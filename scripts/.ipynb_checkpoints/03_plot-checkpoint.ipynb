# %% [markdown]
# ### Plot

# %%
import pandas # to read the data frame

# %%
anz= pandas.read_csv('../data/gapminder_gdp_oceania.csv' , index_col='country')
europe=pandas.read_csv('../data/gapminder_gdp_europe.csv' , index_col='country')

# %%
# %who
# Out:
# anz	 europe	 pandas

# %%
#create a plot in the same cell
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#add a plot to transform anz
anz.T.plot()

# %%
anz.columns
# Out:
# Index(['gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962', 'gdpPercap_1967',
#        'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982', 'gdpPercap_1987',
#        'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002', 'gdpPercap_2007'],
#       dtype='object')

# %%
#format column names to only the numbers
years=anz.columns.str.strip('gdpPercarp_')

# %%
anz.columns=years

# %%
anz.columns

anz.T.plot()
plt.ylabel('GDP per Cap')
# Out:
# Text(0.5,0,'cap')

# %%
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('seaborn-colorblind')
europe.plot()

# %%
europe.columns =years
plt.style.use('default')
europe.plot(kind='box')

# %%
dp_i = europe.loc[('Italy', 'Ireland', 'Iceland'),]

plt.plot(years, gdp_i.iloc[0], 'g--', label='Italy')
plt.plot(years, gdp_i.iloc[1], 'y--', label='Ireland')
plt.plot(years, gdp_i.iloc[2], 'r--', label='Iceland')
plt.legend(loc= 'best')
plt.xlabel('Years')
plt.ylabel('GDP per Cap')
plt.title('GDP per cap in Italy, Ireland and Iceland')
# Out:
# Text(0.5,1,'GDP per cap in Italy, Ireland and Iceland')
